# %%
# %matplotlib inline

# %%
# Import dependencies
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Adding the "o" as a parameter, this switches it from line chart to scatter plot
plt.plot(x_axis, y_axis, 'o')

# %%
# Can use the plt.scatter function as well as the above method
plt.scatter(x_axis, y_axis)

# %%
# SKILL DRILL
# Create plot
plt.scatter(y_axis, x_axis,color = "red", label='Chicago')
# Invert y-axis
plt.gca().invert_yaxis()
# Add the legend.
plt.legend()
# Create labels for the x and y axes.
plt.xlabel("Fare($)")
plt.ylabel("Date")
# Set the x limit between 0 and 45.
plt.xlim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Out:
# Text(0.5, 1.0, 'PyBer Fare by Month')
